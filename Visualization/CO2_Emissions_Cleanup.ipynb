# %% [markdown]
# ## CO2 Emissions

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies

from geopy.geocoders import Nominatim
import pandas as pd

# %%
# Read csv

df=pd.read_csv('CO2 Emissions.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      194 non-null    object
#  1   Data source  194 non-null    object
#  2   Sector       194 non-null    object
#  3   Gas          194 non-null    object
#  4   Unit         194 non-null    object
#  5   2019         194 non-null    float64
#  6   2018         194 non-null    float64
#  7   2017         194 non-null    float64
#  8   2016         194 non-null    float64
#  9   2015         194 non-null    float64
#  10  2014         194 non-null    float64
#  11  2013         194 non-null    float64
#  12  2012         194 non-null    float64
#  13  2011         194 non-null    float64
#  14  2010         194 non-null    float64
#  15  2009         194 non-null    float64
#  16  2008         194 non-null    float64
#  17  2007         194 non-null    float64
# ...

# %%
df.size
# Out:
# 6790

# %%
df.shape
# Out:
# (194, 35)

# %%
# Check for null values per column

df.isnull().sum()
# Out:
# Country        0
# Data source    0
# Sector         0
# Gas            0
# Unit           0
# 2019           0
# 2018           0
# 2017           0
# 2016           0
# 2015           0
# 2014           0
# 2013           0
# 2012           0
# 2011           0
# 2010           0
# 2009           0
# 2008           0
# 2007           0
# 2006           0
# 2005           0
# 2004           0
# 2003           0
# 2002           0
# 2001           0
# 2000           0
# 1999           0
# 1998           0
# 1997           0
# 1996           0
# 1995           0
# 1994           0
# 1993           0
# 1992           0
# 1991           0
# 1990           1
# dtype: int64

# %%
# Add latitude and longtitude

def get_lat_long(country):
    geolocator= Nominatim(user_agent= 'my_app')
    location = geolocator.geocode(country)
    return(location.latitude, location.longitude)

# %%
df['Latitude'] = df['Country'].apply(lambda x: get_lat_long(x)[0])
df['Longitude'] = df['Country'].apply(lambda x: get_lat_long(x)[1])

# %%
# Check for addition of latitude and Longitude

df.head()
# Out:
#        Country Data source                Sector  Gas    Unit    2019    2018  \
# 0  Afghanistan        CAIT  Total including LUCF  CO2  MtCO2e    6.23    6.22
# 1      Albania        CAIT  Total including LUCF  CO2  MtCO2e    4.59    4.87
# 2      Algeria        CAIT  Total including LUCF  CO2  MtCO2e  171.45  165.74
# 3      Andorra        CAIT  Total including LUCF  CO2  MtCO2e    0.50    0.49
# 4       Angola        CAIT  Total including LUCF  CO2  MtCO2e   60.80   59.55
#
#      2017    2016    2015  ...   1997   1996   1995   1994   1993   1992  \
# 0    4.94    5.46    5.70  ...  -1.29  -1.21  -1.15  -1.10  -1.05  -1.00
# 1    4.91    4.24    3.78  ...   1.66   2.13   2.12   2.26   2.25   2.41
# 2  158.53  155.10  155.65  ...  75.01  76.70  77.01  74.18  72.79  67.42
# 3    0.47    0.47    0.47  ...   0.47   0.45   0.43   0.41   0.41   0.41
# 4   59.84   65.36   67.25  ...  26.43  25.71  22.99  21.57  19.54  17.15
#
#     1991   1990   Latitude  Longitude
# ...

# %%
df=df.dropna()

# %%
df.size
# Out:
# 7141

# %%
df.shape
# Out:
# (193, 37)

# %%
df.head()
# Out:
#        Country Data source                Sector  Gas    Unit    2019    2018  \
# 0  Afghanistan        CAIT  Total including LUCF  CO2  MtCO2e    6.23    6.22
# 1      Albania        CAIT  Total including LUCF  CO2  MtCO2e    4.59    4.87
# 2      Algeria        CAIT  Total including LUCF  CO2  MtCO2e  171.45  165.74
# 3      Andorra        CAIT  Total including LUCF  CO2  MtCO2e    0.50    0.49
# 4       Angola        CAIT  Total including LUCF  CO2  MtCO2e   60.80   59.55
#
#      2017    2016    2015  ...   1997   1996   1995   1994   1993   1992  \
# 0    4.94    5.46    5.70  ...  -1.29  -1.21  -1.15  -1.10  -1.05  -1.00
# 1    4.91    4.24    3.78  ...   1.66   2.13   2.12   2.26   2.25   2.41
# 2  158.53  155.10  155.65  ...  75.01  76.70  77.01  74.18  72.79  67.42
# 3    0.47    0.47    0.47  ...   0.47   0.45   0.43   0.41   0.41   0.41
# 4   59.84   65.36   67.25  ...  26.43  25.71  22.99  21.57  19.54  17.15
#
#     1991   1990   Latitude  Longitude
# ...

# %%
# Drop columns

CO2_df=df.drop(columns=['Data source', 'Sector'])
CO2_df.head()
# Out:
#        Country  Gas    Unit    2019    2018    2017    2016    2015    2014  \
# 0  Afghanistan  CO2  MtCO2e    6.23    6.22    4.94    5.46    5.70    4.63
# 1      Albania  CO2  MtCO2e    4.59    4.87    4.91    4.24    3.78    3.98
# 2      Algeria  CO2  MtCO2e  171.45  165.74  158.53  155.10  155.65  147.11
# 3      Andorra  CO2  MtCO2e    0.50    0.49    0.47    0.47    0.47    0.46
# 4       Angola  CO2  MtCO2e   60.80   59.55   59.84   65.36   67.25   65.23
#
#      2013  ...   1997   1996   1995   1994   1993   1992   1991   1990  \
# 0    5.74  ...  -1.29  -1.21  -1.15  -1.10  -1.05  -1.00  -0.16  -0.01
# 1    3.59  ...   1.66   2.13   2.12   2.26   2.25   2.41   4.25   6.17
# 2  138.40  ...  75.01  76.70  77.01  74.18  72.79  67.42  67.00  63.51
# 3    0.48  ...   0.47   0.45   0.43   0.41   0.41   0.41   0.41   0.41
# 4   62.56  ...  26.43  25.71  22.99  21.57  19.54  17.15  16.95  16.84
#
#     Latitude  Longitude
# 0  33.768006  66.238514
# 1  41.000028  19.999962
# ...

# %%
# Open a file in write mode
with open('CO2_Emission.csv', 'w') as f:
    
    # Save the dataframe to the file
    CO2_df.to_csv(f, index= False)
